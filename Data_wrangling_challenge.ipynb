# %% [markdown]
# # Data Wrangling Challenge
# ### Pull and manipulate the API data
#
# The point of this exercise is to try data enrichment with data from external APIs. We are going to take data about car crashes in Monroe County, Indiana from 2003 to 2015 and try to figure out the weather during the accident and how many bars there are in the area. We will work with two different APIs during this challenge:
#
# - Foursquare API
# - World Weather Online API
#
# We will try to find correlations between the severity of crash and weather/number of bars in the area. To indicate the severity of a crash, we will use column `Injury Type`.

# %% [markdown]
# ## Data
#
# The data for this exercise can be found [here](https://drive.google.com/file/d/1_KF9oIJV8cB8i3ngA4JPOLWIE_ETE6CJ/view?usp=sharing).
#
# Just run the cells below to get your data ready. Little help from us.

# %%
import pandas as pd
from dotenv import load_dotenv
import os
import requests
from matplotlib import test
import json
from pandas import json_normalize

# %%
data = pd.read_csv("monroe-county-crash-data2003-to-2015.csv", encoding="unicode_escape")
# ========================
# preparing data
data.dropna(subset=['Latitude', 'Longitude'], inplace=True)
# creation of variable with lon and lat together
data['ll'] = data['Latitude'].astype(str) + ',' + data['Longitude'].astype(str)
data = data[data['ll'] != '0.0,0.0']
print(data.shape)
data.head(3)

# %%
type(data['ll'][0])
# Out:
# str

# %% [markdown]
# # Foursquare API
#
# Foursquare API documentation is [here](https://developer.foursquare.com/)
#
# 1. Start a foursquare application and get your keys.
# 2. For each crash, create the function **get_venues** that will pull bars in the radius of 5km around the crash
#
# #### example
# `get_venues('48.146394, 17.107969')`
#
# 3. Find a relationship (if there is any) between number of bars in the area and severity of the crash.
#
# HINTs:
# - check out python package "foursquare" (no need to send HTTP requests directly with library `requests`)
# - **categoryId** for bars and nightlife needs to be found in the [foursquare API documentation](https://developer.foursquare.com/docs/api-reference/venues/search/)

# %%
# 2022-10-02 21:38 Overall approach:
    # Used Foursquare API to find bars near 6 of the accidents (first 3 and last 3)
    # Found mean number of bars according to Injury type
    # Conclusion: Unable to determine if there's a signficant relationship between accident severity and number of nearby 
    # bars  due to small sample size.

# %%
# 2022-10-02 10:39: Original function. No longer needed.
def get_venues(coordinates,category='13003',radius=5):
    """Parameters:
    - Coordinates: (string) Latitude and longitude, separated by a comma.
    - Category: (string, optional) Category of place. If blank default is 13003 for 
    'Dining and Drinking > Bar'
    - Radius: (integer, optional) Radius of search results.
    """
    radius = int(radius)
    urlAppend = f'?ll={coordinates}&radius={radius}&categories={category}'
    search_URL = "https://api.foursquare.com/v3/places/search"+urlAppend
    
    return search_URL

get_venues('48,17')
# Out:
# 'https://api.foursquare.com/v3/places/search?ll=48,17&radius=5&categories=13003'

# %%
# 2022-10-02 10:40 Custom function 
def get_venues(coordinates,urlEP='https://api.foursquare.com/v3/places/search',category='13003',radius=5000):
    """Parameters:
    - Coordinates: (string) Latitude and longitude, separated by a comma.
    - Term: (string, optional) Search term to use. Default is 'coworking'.
    - urlEP: (string, optional) Root for API endpoint URL. Default for Foursquare Places.
    - Category: (string, optional) Category of place. 
        If blank default is 13003 for 'Dining and Drinking > Bar'
            - 11128 for 'Business and Professional Services > Office > Coworking Space'
            - 13003 for 'Dining and Drinking > Bar'. 
        - In Yelp: Ethiopian restaurants: 'ethiopian'
    - Radius: (integer, optional) Radius of search results.
    
    Returns:
    - URL for API call (string)
    """
    urlEP=str(urlEP)
    radius = int(radius)
    category=str(category)

    if urlEP.find('api.yelp') > 0:
        coordinates = str.split(coordinates,sep=',')
        urlAppend = f'?latitude={coordinates[0]}&longitude={coordinates[1]}&radius={radius}&term={category}' # yelp
    else:
        urlAppend = f'?ll={coordinates}&radius={radius}&categories={category}' # Default is for foursquare
    request_URL=urlEP+urlAppend
    return request_URL

# %%
# Add searchURL to dataframe
# data['foursquareURL'] = str(get_venues(data['ll']))
data.head(5)
# 2022-10-02 20:09: Turns out that search URL becomes a weird data type when retrieved from the DF, so I removed it.
# Out:
#    Master Record Number  Year  Month  Day Weekend?    Hour Collision Type  \
# 0             902363382  2015      1    5  Weekday     0.0          2-Car
# 1             902364268  2015      1    6  Weekday  1500.0          2-Car
# 2             902364412  2015      1    6  Weekend  2300.0          2-Car
# 3             902364551  2015      1    7  Weekend   900.0          2-Car
# 4             902364615  2015      1    7  Weekend  1100.0          2-Car
#
#           Injury Type                         Primary Factor  \
# 0   No injury/unknown  OTHER (DRIVER) - EXPLAIN IN NARRATIVE
# 1   No injury/unknown                  FOLLOWING TOO CLOSELY
# 2  Non-incapacitating              DISREGARD SIGNAL/REG SIGN
# 3  Non-incapacitating          FAILURE TO YIELD RIGHT OF WAY
# 4   No injury/unknown          FAILURE TO YIELD RIGHT OF WAY
#
#        Reported_Location   Latitude  Longitude                        ll
# 0             1ST & FESS  39.159207 -86.525874  39.15920668,-86.52587356
# 1          2ND & COLLEGE  39.161440 -86.534848       39.16144,-86.534848
# 2  BASSWOOD & BLOOMFIELD  39.149780 -86.568890  39.14978027,-86.56889006
# 3         GATES & JACOBS  39.165655 -86.575956    39.165655,-86.57595635
# 4                  W 3RD  39.164848 -86.579625    39.164848,-86.57962482

# %%
# See what injury types there are
data['Injury Type'].value_counts()
# Out:
# No injury/unknown     37467
# Non-incapacitating    10427
# Incapacitating         1003
# Fatal                   108
# Name: Injury Type, dtype: int64

# %%
#set the keys
apiKey = os.environ["API_FOURSQUARE"]
# apiKey
# foursquare_secret = os.environ[""]

# %%
url = "https://api.foursquare.com/v3/places/search"

headers = {
    "Accept": "application/json",
    "Authorization": apiKey
}

# response = requests.request("GET", url, headers=headers)
# Out:
# {"results":[{"fsq_id":"4c44da1af0bdd13aee2ccacc","categories":[{"id":16023,"name":"Lake","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/parks_outdoors/lake_","suffix":".png"}}],"chains":[],"distance":1145,"geocodes":{"main":{"latitude":49.163382,"longitude":-123.997793}},"link":"/v3/places/4c44da1af0bdd13aee2ccacc","location":{"country":"CA","cross_street":"","formatted_address":"Nanaimo BC","locality":"Nanaimo","region":"BC"},"name":"Westwood Lake","related_places":{},"timezone":"America/Vancouver"},{"fsq_id":"4b5516daf964a520cada27e3","categories":[{"id":10006,"name":"Bowling Alley","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/arts_entertainment/bowling_","suffix":".png"}}],"chains":[],"distance":901,"geocodes":{"main":{"latitude":49.168469,"longitude":-123.986414},"roof":{"latitude":49.168469,"longitude":-123.986414}},"link":"/v3/places/4b5516daf964a520cada27e3","location":{"address":"171 Calder Rd","country":"CA","cross_street":"","formatted_address":"171 Calder Rd, Nanaimo BC V9R 6J2","locality":"Nanaimo","neighborhood":["Central Nanaimo"],"postcode":"V9R 6J2","region":"BC"},"name":"Splitsville Entertainment Ltd","related_places":{},"timezone":"America/Vancouver"},{"fsq_id":"4b75aceef964a520211c2ee3","categories":[{"id":13031,"name":"Burger Joint","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/burger_","suffix":".png"}},{"id":13072,"name":"Asian Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/asian_","suffix":".png"}},{"id":13379,"name":"Vietnamese Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/vietnamese_","suffix":".png"}}],"chains":[],"distance":2694,"geocodes":{"main":{"latitude":49.185781,"longitude":-123.983797},"roof":{"latitude":49.185781,"longitude":-123.983797}},"link":"/v3/places/4b75aceef964a520211c2ee3","location":{"address":"1925 Bowen Rd","address_extended":"# 19","country":"CA","cross_street":"","formatted_address":"1925 Bowen Rd, Nanaimo BC V9S 1H1","locality":"Nanaimo","neighborhood":["Central Nanaimo"],"postcode":"V9S 1H1","region":"BC"},"name":"Huong Lan Restaurant","related_places":{},"timezone":"America/Vancouver"},{"fsq_id":"4f1b74dde4b0aa5094e4d76f","categories":[{"id":13303,"name":"Mexican Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/mexican_","suffix":".png"}}],"chains":[],"distance":2307,"geocodes":{"main":{"latitude":49.15531,"longitude":-123.952181},"roof":{"latitude":49.15531,"longitude":-123.952181}},"link":"/v3/places/4f1b74dde4b0aa5094e4d76f","location":{"address":"550 5th St","address_extended":"# 205","country":"CA","cross_street":"","formatted_address":"550 5th St, Nanaimo BC V9R 1P1","locality":"Nanaimo","neighborhood":["Nanaimo"],"postcode":"V9R 1P1","region":"BC"},"name":"Baby Salsa Mexican Restaurant","related_places":{},"timezone":"America/Vancouver"},{"fsq_id":"4b92e19bf964a520102434e3","categories":[{"id":16037,"name":"Playground","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/parks_outdoors/playground_","suffix":".png"}}],"chains":[],"distance":3376,"geocodes":{"main":{"latitude":49.171264,"longitude":-123.9387}},"link":"/v3/places/4b92e19bf964a520102434e3","location":{"country":"CA","cross_street":"","formatted_address":"Nanaimo BC","locality":"Nanaimo","region":"BC"},"name":"Maffeo Sutton Park","related_places":{},"timezone":"America/Vancouver"},{"fsq_id":"4b483084f964a520c54926e3","categories":[{"id":13177,"name":"Greek Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/greek_","suffix":".png"}}],"chains":[],"distance":3036,"geocodes":{"main":{"latitude":49.164634,"longitude":-123.940973},"roof":{"latitude":49.164634,"longitude":-123.940973}},"link":"/v3/places/4b483084f964a520c54926e3","location":{"address":"347 Wesley St","country":"CA","cross_street":"","formatted_address":"347 Wesley St, Nanaimo BC V9R 2T5","locality":"Nanaimo","neighborhood":["Old City"],"postcode":"V9R 2T5","region":"BC"},"name":"Asteras Greek Taverna"," ...

# %%
# play around with indexing
data.iloc[0,:]
# Out:
# Master Record Number                                            902363382
# Year                                                                 2015
# Month                                                                   1
# Day                                                                     5
# Weekend?                                                          Weekday
# Hour                                                                  0.0
# Collision Type                                                      2-Car
# Injury Type                                             No injury/unknown
# Primary Factor                      OTHER (DRIVER) - EXPLAIN IN NARRATIVE
# Reported_Location                                              1ST & FESS
# Latitude                                                        39.159207
# Longitude                                                      -86.525874
# ll                                               39.15920668,-86.52587356
# foursquareURL           https://api.foursquare.com/v3/places/search?ll...
# Name: 0, dtype: object

# %%
# Make the GET request for Foursquare for first few accidents in the dataset. 

responses = dict()
for crash in range(3):
    url = get_venues(data['ll'][crash])
    print(url)
    responses[str(crash)] = requests.get(url, headers=headers)
    # responses[str(data['Master Record Number'][crash])] = 'test' # 2022-10-02 20:11: Originally planned to index responses
        # by Master Record Number, but then realized using the index is easier.
responses
# Out:
# https://api.foursquare.com/v3/places/search?ll=39.15920668,-86.52587356&radius=5000&categories=13003
# https://api.foursquare.com/v3/places/search?ll=39.16144,-86.534848&radius=5000&categories=13003
# https://api.foursquare.com/v3/places/search?ll=39.14978027,-86.56889006&radius=5000&categories=13003
# {'0': <Response [200]>, '1': <Response [200]>, '2': <Response [200]>}

# %%
# Loop through API responses to create all the dataframes at once. 
dfs = dict()
for key, value in responses.items():
    # print(key, value.json())
    json = responses[key].json()
    dfs[key] = json_normalize(json, record_path='results')

# %%
print(dfs['0'].shape)
dfs['0'].head(3)
# Out:
# (10, 23)
#                      fsq_id  \
# 0  507c2800e4b0b5e9215c9444
# 1  5249fca911d20ce66163e75a
# 2  4ae33784f964a520cd9121e3
#
#                                           categories chains  distance  \
# 0  [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...     []      1151
# 1  [{'id': 13009, 'name': 'Cocktail Bar', 'icon':...     []       966
# 2  [{'id': 13025, 'name': 'Wine Bar', 'icon': {'p...     []      1869
#
#                                   link                             name  \
# 0  /v3/places/507c2800e4b0b5e9215c9444                          The Tap
# 1  /v3/places/5249fca911d20ce66163e75a                 Cardinal Spirits
# 2  /v3/places/4ae33784f964a520cd9121e3  Upland Brewing Company Brew Pub
#
#                        timezone  geocodes.main.latitude  \
# 0  America/Indiana/Indianapolis               39.166841
# 1  America/Indiana/Indianapolis               39.156283
# 2  America/Indiana/Indianapolis               39.173503
#
#    geocodes.main.longitude  geocodes.roof.latitude  ...  location.country  \
# 0               -86.535183               39.166841  ...                US
# 1               -86.536519               39.156283  ...                US
# 2               -86.537557               39.173503  ...                US
#
#   location.cross_street  location.dma  \
# 0                        Indianapolis
# 1                        Indianapolis
# 2         at Rogers St.  Indianapolis
#
#                           location.formatted_address location.locality  \
# 0           101 N College Ave, Bloomington, IN 47404       Bloomington
# 1             922 S Morton St, Bloomington, IN 47403       Bloomington
# 2  350 W 11th St (at Rogers St.), Bloomington, IN...       Bloomington
#
#   location.neighborhood location.postcode location.region location.po_box  \
# 0           [Arlington]             47404              IN             NaN
# 1                   NaN             47403              IN   P.O. Box 2282
# 2           [Arlington]             47404              IN             NaN
#
#   related_places.children
# 0                     NaN
# 1                     NaN
# 2                     NaN
#
# [3 rows x 23 columns]

# %%
# Play around with indexing the bottom of the dataframe
data['Master Record Number'].iloc[-1]
# Out:
# 900046599

# %%
# Make the GET request for Foursquare for last 3 accidents in the dataset. 
for crash in range(-4,-1):
    # print(crash)
    url = get_venues(data['ll'].iloc[crash]) # Need to use .iloc to index the last rows of the dataframe
    print(url)
    responses[str(crash)] = requests.get(url, headers=headers)
responses
# Out:
# https://api.foursquare.com/v3/places/search?ll=39.002752,-86.463856&radius=5000&categories=13003
# https://api.foursquare.com/v3/places/search?ll=38.99232624,-86.53725171&radius=5000&categories=13003
# https://api.foursquare.com/v3/places/search?ll=38.99152,-86.448784&radius=5000&categories=13003
# {'0': <Response [200]>,
#  '1': <Response [200]>,
#  '2': <Response [200]>,
#  '-4': <Response [200]>,
#  '-3': <Response [200]>,
#  '-2': <Response [200]>}

# %%
# Loop through API responses to create all the dataframes for new responses. 
for key, value in responses.items():
    # print(key, value.json())
    json = responses[key].json()
    dfs[key] = json_normalize(json, record_path='results')
# Out:
# {'0':                      fsq_id  \
#  0  507c2800e4b0b5e9215c9444
#  1  5249fca911d20ce66163e75a
#  2  4ae33784f964a520cd9121e3
#  3  5b07718bd3cce8002cd23f9b
#  4  5064d1ebe4b0675fa422bb50
#  5  535ae26c498e51ccd1e78ace
#  6  5390b62d498e1eb46529a20a
#  7  4ae3d332f964a5202f9921e3
#  8  53ea4a71498e76cdafe2ee7c
#  9  4aebd299f964a520e3c421e3
#
#                                            categories chains  distance  \
#  0  [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...     []      1151
#  1  [{'id': 13009, 'name': 'Cocktail Bar', 'icon':...     []       966
#  2  [{'id': 13025, 'name': 'Wine Bar', 'icon': {'p...     []      1869
#  3  [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...     []      1393
#  4  [{'id': 10032, 'name': 'Night Club', 'icon': {...     []       998
#  5  [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...     []       936
#  6  [{'id': 13002, 'name': 'Bakery', 'icon': {'pre...     []      1258
#  7  [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...     []      1166
#  8  [{'id': 13009, 'name': 'Cocktail Bar', 'icon':...     []      2516
#  9  [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...     []      1153
#
#                                    link                             name  \
#  0  /v3/places/507c2800e4b0b5e9215c9444                          The Tap
#  1  /v3/places/5249fca911d20ce66163e75a                 Cardinal Spirits
#  2  /v3/places/4ae33784f964a520cd9121e3  Upland Brewing Company Brew Pub
#  3  /v3/places/5b07718bd3cce8002cd23f9b       Switchyard Brewing Company
#  4  /v3/places/5064d1ebe4b0675fa422bb50                    The Back Door
#  5  /v3/places/535ae26c498e51ccd1e78ace            Big Woods Bloomington
#  6  /v3/places/5390b62d498e1eb46529a20a            Feast Market & Cellar
#  7  /v3/places/4ae3d332f964a5202f9921e3  The Irish Lion Restaurant & Pub
#  8  /v3/places/53ea4a71498e76cdafe2ee7c                           C3 Bar
#  9  /v3/places/4aebd299f964a520e3c421e3                    The Alley Bar
#
#                         timezone  geocodes.main.latitude  \
#  0  America/Indiana/Indianapolis               39.166841
#  1  America/Indiana/Indianapolis               39.156283
#  2  America/Indiana/Indianapolis               39.173503
#  3  America/Indiana/Indianapolis               39.170241
#  4  America/Indiana/Indianapolis               39.165239
#  5  America/Indiana/Indianapolis               39.167230
#  6  America/Indiana/Indianapolis               39.153561
#  7  America/Indiana/Indianapolis               39.166831
#  8  America/Indiana/Indianapolis               39.149382
#  9  America/Indiana/Indianapolis               39.166716
#
#     geocodes.main.longitude  geocodes.roof.latitude  ...  location.country  \
#  0               -86.535183               39.166841  ...                US
#  1               -86.536519               39.156283  ...                US
#  2               -86.537557               39.173503  ...                US
#  3               -86.533919               39.170241  ...                US
#  4               -86.534629                     NaN  ...                US
#  5               -86.529634               39.167230  ...                US
#  6               -86.538329               39.153561  ...                US
#  7               -86.535648               39.166831  ...                US
#  8               -86.499610               39.149382  ...                US
#  9               -86.535315               39.166716  ...                US
#
#    location.cross_street  location.dma  \
#  0                        Indianapolis
#  1                        Indianapolis
#  2         at Rogers St.  Indianapolis
#  3            9th Street  Indianapolis
#  4                        Indianapolis
#  5            6th Street  Indianapolis
#  6                        Indianapolis
#  7                        Indianapolis
#  8                        Indianapolis
#  9        at College Ave  Indianapolis
#
#                            location.formatted_address location.locality  \
#  0           101 N College Ave, Bloomington, IN 47404       Bloomington
#  1             922 S Morton St, Bloomington, IN 47403       Bloomington
#  2  350 W 11th St (at Rogers St.), Bloomington, IN...       Bloomington
#  3  419 N Walnut St (9th Street), Bloomington, IN ...       Bloomington
#  4           207 S College Ave, Bloomington, IN 47404       Bloomington
#  5  116 N Grant St (6th Street), Bloomington, IN 4...       Bloomington
#  6          407 W Patterson Dr, Bloomington, IN 47403       Bloomington
#  7          212 W Kirkwood Ave, Bloomington, IN 47404       Bloomington
#  8            1505 S Piazza Dr, Bloomington, IN 47401       Bloomington
#  9  210 W Kirkwood Ave (at College Ave), Bloomingt...       Bloomington
#
#    location.neighborhood location.postcode location.region location.po_box  \
#  0           [Arlington]             47404              IN             NaN
#  1                   NaN             47403              IN   P.O. Box 2282
#  2           [Arlington]             47404              IN             NaN
#  3           [Arlington]             47404              IN             NaN
#  4           [Arlington]             47404              IN             NaN
#  5        [Marlin Hills]             47408              IN             NaN
#  6                   NaN             47403              IN             NaN
#  7           [Arlington]             47404              IN             NaN
#  8                   NaN             47401              IN             NaN
#  9           [Arlington]             47404              IN             NaN
#
#                               related_places.children
#  0                                                NaN
#  1                                                NaN
#  2                                                NaN
#  3  [{'fsq_id': '5f2c92aca9d86a7303abbdce', 'name'...
#  4                                                NaN
#  5                                                NaN
#  6                                                NaN
#  7                                                NaN
#  8                                                NaN
#  9                                                NaN
#
#  [10 rows x 23 columns],
#  '1':                      fsq_id  \
#  0  507c2800e4b0b5e9215c9444
#  1  5249fca911d20ce66163e75a
#  2  4ae33784f964a520cd9121e3
#  3  5b07718bd3cce8002cd23f9b
#  4  5064d1ebe4b0675fa422bb50
#  5  4ae3d332f964a5202f9921e3
#  6  5390b62d498e1eb46529a20a
#  7  535ae26c498e51ccd1e78ace
#  8  4aebd299f964a520e3c421e3
#  9  4b270d10f964a5206d8424e3
#
#                                            categories chains  distance  \
#  0  [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...     []       580
#  1  [{'id': 13009, 'name': 'Cocktail Bar', 'icon':...     []       591
#  2  [{'id': 13025, 'name': 'Wine Bar', 'icon': {'p...     []      1354
#  3  [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...     []       971
#  4  [{'id': 10032, 'name': 'Night Club', 'icon': {...     []       417
#  5  [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...     []       580
#  6  [{'id': 13002, 'name': 'Bakery', 'icon': {'pre...     []       945
#  7  [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...     []       776
#  8  [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...     []       573
#  9  [{'id': 10039, 'name': 'Music Venue', 'icon': ...     []       490
#
#                                    link                             name  \
#  0  /v3/places/507c2800e4b0b5e9215c9444                          The Tap
#  1  /v3/places/5249fca911d20ce66163e75a                 Cardinal Spirits
#  2  /v3/places/4ae33784f964a520cd9121e3  Upland Brewing Company Brew Pub
#  3  /v3/places/5b07718bd3cce8002cd23f9b       Switchyard Brewing Company
#  4  /v3/places/5064d1ebe4b0675fa422bb50                    The Back Door
#  5  /v3/places/4ae3d332f964a5202f9921e3  The Irish Lion Restaurant & Pub
#  6  /v3/places/5390b62d498e1eb46529a20a            Feast Market & Cellar
#  7  /v3/places/535ae26c498e51ccd1e78ace            Big Woods Bloomington
#  8  /v3/places/4aebd299f964a520e3c421e3                    The Alley Bar
#  9  /v3/places/4b270d10f964a5206d8424e3                       The Bishop
#
#                         timezone  geocodes.main.latitude  \
#  0  America/Indiana/Indianapolis               39.166841
#  1  America/Indiana/Indianapolis               39.156283
#  2  America/Indiana/Indianapolis               39.173503
#  3  America/Indiana/Indianapolis               39.170241
#  4  America/Indiana/Indianapolis               39.165239
#  5  America/Indiana/Indianapolis               39.166831
#  6  America/Indiana/Indianapolis               39.153561
#  7  America/Indiana/Indianapolis               39.167230
#  8  America/Indiana/Indianapolis               39.166716
#  9  America/Indiana/Indianapolis               39.165806
#
#     geocodes.main.longitude  geocodes.roof.latitude  ...  location.country  \
#  0               -86.535183               39.166841  ...                US
#  1               -86.536519               39.156283  ...                US
#  2               -86.537557               39.173503  ...                US
#  3               -86.533919               39.170241  ...                US
#  4               -86.534629                     NaN  ...                US
#  5               -86.535648               39.166831  ...                US
#  6               -86.538329               39.153561  ...                US
#  7               -86.529634               39.167230  ...                US
#  8               -86.535315               39.166716  ...                US
#  9               -86.533333               39.165806  ...                US
#
#    location.cross_street  location.dma  \
#  0                        Indianapolis
#  1                        Indianapolis
#  2         at Rogers St.  Indianapolis
#  3            9th Street  Indianapolis
#  4                        Indianapolis
#  5                        Indianapolis
#  6                        Indianapolis
#  7            6th Street  Indianapolis
#  8        at College Ave  Indianapolis
#  9                        Indianapolis
#
#                            location.formatted_address location.locality  \
#  0           101 N College Ave, Bloomington, IN 47404       Bloomington
#  1             922 S Morton St, Bloomington, IN 47403       Bloomington
#  2  350 W 11th St (at Rogers St.), Bloomington, IN...       Bloomington
#  3  419 N Walnut St (9th Street), Bloomington, IN ...       Bloomington
#  4           207 S College Ave, Bloomington, IN 47404       Bloomington
#  5          212 W Kirkwood Ave, Bloomington, IN 47404       Bloomington
#  6          407 W Patterson Dr, Bloomington, IN 47403       Bloomington
#  7  116 N Grant St (6th Street), Bloomington, IN 4...       Bloomington
#  8  210 W Kirkwood Ave (at College Ave), Bloomingt...       Bloomington
#  9             123 S Walnut St, Bloomington, IN 47404       Bloomington
#
#    location.neighborhood location.postcode location.region location.po_box  \
#  0           [Arlington]             47404              IN             NaN
#  1                   NaN             47403              IN   P.O. Box 2282
#  2           [Arlington]             47404              IN             NaN
#  3           [Arlington]             47404              IN             NaN
#  4           [Arlington]             47404              IN             NaN
#  5           [Arlington]             47404              IN             NaN
#  6                   NaN             47403              IN             NaN
#  7        [Marlin Hills]             47408              IN             NaN
#  8           [Arlington]             47404              IN             NaN
#  9        [Marlin Hills]             47404              IN             NaN
#
#                               related_places.children
#  0                                                NaN
#  1                                                NaN
#  2                                                NaN
#  3  [{'fsq_id': '5f2c92aca9d86a7303abbdce', 'name'...
#  4                                                NaN
#  5                                                NaN
#  6                                                NaN
#  7                                                NaN
#  8                                                NaN
#  9                                                NaN
#
#  [10 rows x 23 columns],
#  '2':                      fsq_id  \
#  0  5249fca911d20ce66163e75a
#  1  507c2800e4b0b5e9215c9444
#  2  4ae33784f964a520cd9121e3
#  3  50032808e4b0644141be1e8c
#  4  5b07718bd3cce8002cd23f9b
#  5  5390b62d498e1eb46529a20a
#  6  5064d1ebe4b0675fa422bb50
#  7  4ae3d332f964a5202f9921e3
#  8  535ae26c498e51ccd1e78ace
#  9  4aebd299f964a520e3c421e3
#
#                                            categories chains  distance  \
#  0  [{'id': 13009, 'name': 'Cocktail Bar', 'icon':...     []      2888
#  1  [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...     []      3458
#  2  [{'id': 13025, 'name': 'Wine Bar', 'icon': {'p...     []      3782
#  3  [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...     []      2920
#  4  [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...     []      3777
#  5  [{'id': 13002, 'name': 'Bakery', 'icon': {'pre...     []      2658
#  6  [{'id': 10032, 'name': 'Night Club', 'icon': {...     []      3421
#  7  [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...     []      3439
#  8  [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...     []      3895
#  9  [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...     []      3445
#
#                                    link  \
#  0  /v3/places/5249fca911d20ce66163e75a
#  1  /v3/places/507c2800e4b0b5e9215c9444
#  2  /v3/places/4ae33784f964a520cd9121e3
#  3  /v3/places/50032808e4b0644141be1e8c
#  4  /v3/places/5b07718bd3cce8002cd23f9b
#  5  /v3/places/5390b62d498e1eb46529a20a
#  6  /v3/places/5064d1ebe4b0675fa422bb50
#  7  /v3/places/4ae3d332f964a5202f9921e3
#  8  /v3/places/535ae26c498e51ccd1e78ace
#  9  /v3/places/4aebd299f964a520e3c421e3
#
#                                              name  \
#  0                               Cardinal Spirits
#  1                                        The Tap
#  2                Upland Brewing Company Brew Pub
#  3  Upland Brewing Company Brewery & Tasting Room
#  4                     Switchyard Brewing Company
#  5                          Feast Market & Cellar
#  6                                  The Back Door
#  7                The Irish Lion Restaurant & Pub
#  8                          Big Woods Bloomington
#  9                                  The Alley Bar
#
#                         timezone  geocodes.main.latitude  \
#  0  America/Indiana/Indianapolis               39.156283
#  1  America/Indiana/Indianapolis               39.166841
#  2  America/Indiana/Indianapolis               39.173503
#  3  America/Indiana/Indianapolis               39.172394
#  4  America/Indiana/Indianapolis               39.170241
#  5  America/Indiana/Indianapolis               39.153561
#  6  America/Indiana/Indianapolis               39.165239
#  7  America/Indiana/Indianapolis               39.166831
#  8  America/Indiana/Indianapolis               39.167230
#  9  America/Indiana/Indianapolis               39.166716
#
#     geocodes.main.longitude  geocodes.roof.latitude  ...  location.country  \
#  0               -86.536519               39.156283  ...                US
#  1               -86.535183               39.166841  ...                US
#  2               -86.537557               39.173503  ...                US
#  3               -86.586060               39.172394  ...                US
#  4               -86.533919               39.170241  ...                US
#  5               -86.538329               39.153561  ...                US
#  6               -86.534629                     NaN  ...                US
#  7               -86.535648               39.166831  ...                US
#  8               -86.529634               39.167230  ...                US
#  9               -86.535315               39.166716  ...                US
#
#    location.cross_street  location.dma  \
#  0                        Indianapolis
#  1                        Indianapolis
#  2         at Rogers St.  Indianapolis
#  3                   NaN  Indianapolis
#  4            9th Street  Indianapolis
#  5                        Indianapolis
#  6                        Indianapolis
#  7                        Indianapolis
#  8            6th Street  Indianapolis
#  9        at College Ave  Indianapolis
#
#                            location.formatted_address location.locality  \
#  0             922 S Morton St, Bloomington, IN 47403       Bloomington
#  1           101 N College Ave, Bloomington, IN 47404       Bloomington
#  2  350 W 11th St (at Rogers St.), Bloomington, IN...       Bloomington
#  3         4060 W Profile Pkwy, Bloomington, IN 47404       Bloomington
#  4  419 N Walnut St (9th Street), Bloomington, IN ...       Bloomington
#  5          407 W Patterson Dr, Bloomington, IN 47403       Bloomington
#  6           207 S College Ave, Bloomington, IN 47404       Bloomington
#  7          212 W Kirkwood Ave, Bloomington, IN 47404       Bloomington
#  8  116 N Grant St (6th Street), Bloomington, IN 4...       Bloomington
#  9  210 W Kirkwood Ave (at College Ave), Bloomingt...       Bloomington
#
#    location.po_box location.postcode location.region location.neighborhood  \
#  0   P.O. Box 2282             47403              IN                   NaN
#  1             NaN             47404              IN           [Arlington]
#  2             NaN             47404              IN           [Arlington]
#  3             NaN             47404              IN                   NaN
#  4             NaN             47404              IN           [Arlington]
#  5             NaN             47403              IN                   NaN
#  6             NaN             47404              IN           [Arlington]
#  7             NaN             47404              IN           [Arlington]
#  8             NaN             47408              IN        [Marlin Hills]
#  9             NaN             47404              IN           [Arlington]
#
#                               related_places.children
#  0                                                NaN
#  1                                                NaN
#  2                                                NaN
#  3                                                NaN
#  4  [{'fsq_id': '5f2c92aca9d86a7303abbdce', 'name'...
#  5                                                NaN
#  6                                                NaN
#  7                                                NaN
#  8                                                NaN
#  9                                                NaN
#
#  [10 rows x 23 columns],
#  '-4':                      fsq_id  \
#  0  4ff8c5d7e4b08a4c73420d18
#  1  4b512b1cf964a520ac4527e3
#  2  003b4c9d48d84685a8f4f7e2
#
#                                            categories chains  distance  \
#  0  [{'id': 13013, 'name': 'Hotel Bar', 'icon': {'...     []      2148
#  1  [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...     []      4196
#  2  [{'id': 13013, 'name': 'Hotel Bar', 'icon': {'...     []      2164
#
#                                    link               name  \
#  0  /v3/places/4ff8c5d7e4b08a4c73420d18  Wind Jammer Grill
#  1  /v3/places/4b512b1cf964a520ac4527e3        Fairfax Inn
#  2  /v3/places/003b4c9d48d84685a8f4f7e2         Windjammer
#
#                         timezone  geocodes.main.latitude  \
#  0  America/Indiana/Indianapolis               39.016595
#  1  America/Indiana/Indianapolis               39.034080
#  2                           NaN               39.016573
#
#     geocodes.main.longitude  geocodes.roof.latitude  ...  \
#  0               -86.481348               39.016595  ...
#  1               -86.490740               39.034080  ...
#  2               -86.481511               39.016573  ...
#
#     location.census_block location.country location.cross_street  location.dma  \
#  0        181050015022001               US                        Indianapolis
#  1        181050015013035               US           Lake Monroe  Indianapolis
#  2        181050015022001               US                   NaN  Indianapolis
#
#                            location.formatted_address location.locality  \
#  0           9301 S Fairfax Rd, Bloomington, IN 47401       Bloomington
#  1  8660 S Fairfax Rd (Lake Monroe), Bloomington, ...       Bloomington
#  2           9301 S Fairfax Rd, Bloomington, IN 47401       Bloomington
#
#    location.postcode location.region related_places.parent.fsq_id  \
#  0             47401              IN                          NaN
#  1             47401              IN                          NaN
#  2             47401              IN     4b6c3fc1f964a520b02b2ce3
#
#    related_places.parent.name
#  0                        NaN
#  1                        NaN
#  2  Fourwinds Resort & Marina
#
#  [3 rows x 22 columns],
#  '-3':                      fsq_id  \
#  0  595837b9f62f2b5d40ba4c93
#  1  469eb450279e4fc3e5c64f34
#
#                                            categories chains  distance  \
#  0  [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...     []      2922
#  1  [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...     []      3039
#
#                                    link                   name  \
#  0  /v3/places/595837b9f62f2b5d40ba4c93     Steel Horse Saloon
#  1  /v3/places/469eb450279e4fc3e5c64f34  Thirty Seven Junction
#
#                         timezone  geocodes.main.latitude  \
#  0  America/Indiana/Indianapolis               38.967133
#  1                           NaN               38.966391
#
#     geocodes.main.longitude  geocodes.roof.latitude  geocodes.roof.longitude  \
#  0               -86.548099               38.967133               -86.548099
#  1               -86.548425               38.966391               -86.548425
#
#      location.address location.census_block location.country  \
#  0  220 Hillcrest Way       180939506022011               US
#  1  220 Hillcrest Way       180939506022011               US
#
#    location.cross_street  location.dma            location.formatted_address  \
#  0                        Indianapolis  220 Hillcrest Way, Bedford, IN 47421
#  1                   NaN  Indianapolis  220 Hillcrest Way, Bedford, IN 47421
#
#    location.locality location.postcode location.region
#  0           Bedford             47421              IN
#  1           Bedford             47421              IN  ,
#  '-2':                      fsq_id  \
#  0  4ff8c5d7e4b08a4c73420d18
#  1  003b4c9d48d84685a8f4f7e2
#
#                                            categories chains  distance  \
#  0  [{'id': 13013, 'name': 'Hotel Bar', 'icon': {'...     []      3951
#  1  [{'id': 13013, 'name': 'Hotel Bar', 'icon': {'...     []      3967
#
#                                    link               name  \
#  0  /v3/places/4ff8c5d7e4b08a4c73420d18  Wind Jammer Grill
#  1  /v3/places/003b4c9d48d84685a8f4f7e2         Windjammer
#
#                         timezone  geocodes.main.latitude  \
#  0  America/Indiana/Indianapolis               39.016595
#  1                           NaN               39.016573
#
#     geocodes.main.longitude  geocodes.roof.latitude  ...  \
#  0               -86.481348               39.016595  ...
#  1               -86.481511               39.016573  ...
#
#     location.census_block location.country location.cross_street  location.dma  \
#  0        181050015022001               US                        Indianapolis
#  1        181050015022001               US                   NaN  Indianapolis
#
#                   location.formatted_address location.locality  \
#  0  9301 S Fairfax Rd, Bloomington, IN 47401       Bloomington
#  1  9301 S Fairfax Rd, Bloomington, IN 47401       Bloomington
#
#    location.postcode location.region related_places.parent.fsq_id  \
#  0             47401              IN                          NaN
#  1             47401              IN     4b6c3fc1f964a520b02b2ce3
#
#    related_places.parent.name
#  0                        NaN
#  1  Fourwinds Resort & Marina
#
#  [2 rows x 22 columns]}

# %%
# Save the JSON data so it can be referred to without repeating API requests
# Test out with first API request.
responses['0'].json()

with open(f'foursquareBar0','w') as json_file:
    json.dump(responses['0'].json(), json_file)

# %%
for key, value in responses.items():
    # print(key, value.json())
    # print(f'foursquareBar{key}')
    with open(f'foursquareBar{key}.json','w') as json_file:
        json.dump(responses[key].json(), json_file)

# %%
dfs['-4']
# Out:
#                      fsq_id  \
# 0  4ff8c5d7e4b08a4c73420d18
# 1  4b512b1cf964a520ac4527e3
# 2  003b4c9d48d84685a8f4f7e2
#
#                                           categories chains  distance  \
# 0  [{'id': 13013, 'name': 'Hotel Bar', 'icon': {'...     []      2148
# 1  [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...     []      4196
# 2  [{'id': 13013, 'name': 'Hotel Bar', 'icon': {'...     []      2164
#
#                                   link               name  \
# 0  /v3/places/4ff8c5d7e4b08a4c73420d18  Wind Jammer Grill
# 1  /v3/places/4b512b1cf964a520ac4527e3        Fairfax Inn
# 2  /v3/places/003b4c9d48d84685a8f4f7e2         Windjammer
#
#                        timezone  geocodes.main.latitude  \
# 0  America/Indiana/Indianapolis               39.016595
# 1  America/Indiana/Indianapolis               39.034080
# 2                           NaN               39.016573
#
#    geocodes.main.longitude  geocodes.roof.latitude  ...  \
# 0               -86.481348               39.016595  ...
# 1               -86.490740               39.034080  ...
# 2               -86.481511               39.016573  ...
#
#    location.census_block location.country location.cross_street  location.dma  \
# 0        181050015022001               US                        Indianapolis
# 1        181050015013035               US           Lake Monroe  Indianapolis
# 2        181050015022001               US                   NaN  Indianapolis
#
#                           location.formatted_address location.locality  \
# 0           9301 S Fairfax Rd, Bloomington, IN 47401       Bloomington
# 1  8660 S Fairfax Rd (Lake Monroe), Bloomington, ...       Bloomington
# 2           9301 S Fairfax Rd, Bloomington, IN 47401       Bloomington
#
#   location.postcode location.region related_places.parent.fsq_id  \
# 0             47401              IN                          NaN
# 1             47401              IN                          NaN
# 2             47401              IN     4b6c3fc1f964a520b02b2ce3
#
#   related_places.parent.name
# 0                        NaN
# 1                        NaN
# 2  Fourwinds Resort & Marina
#
# [3 rows x 22 columns]

# %%
# Pull the following data:
    # 'Injury Type' from accident data
    # Number of bars from each accident

injury_nBar = [] # This will be a list of dictionaries of relevant info per accident.

for accidentID, df in dfs.items():
    # print(accidentID, df.shape[0]) # test out the iteration
    # print(accidentID, df.shape[0], data['Injury Type'].iloc[int(accidentID)]) # test out the iteration
    injury_nBar.append({
        'accidentID': str(accidentID),
        'Injury Type': data['Injury Type'].iloc[int(accidentID)],
        'nBars': df.shape[0]
    })
# Out:
#   accidentID         Injury Type  nBars
# 0          0   No injury/unknown     10
# 1          1   No injury/unknown     10
# 2          2  Non-incapacitating     10
# 3         -4  Non-incapacitating      3
# 4         -3   No injury/unknown      2
# 5         -2  Non-incapacitating      2

# %%
# Get the average number of bars per injury type.
df_injury_nBar = pd.DataFrame(injury_nBar)
df_injury_nBar.groupby('Injury Type').agg({'nBars': 'mean'})

# Larger sample size required to infer statistical significance.
# Out:
#                        nBars
# Injury Type
# No injury/unknown   7.333333
# Non-incapacitating  5.000000

# %% [markdown]
# # World Weather Online API
#
# World Weather Online API is [here](https://www.worldweatheronline.com/developer/api/historical-weather-api.aspx)
#
# 1. Sign up for FREE api key if you haven't done that before (it's free for **30 days**).
# 2. For each crush, get the weather for the location and date.
# 3. Find a relationship between the weather and severity of the crash.
#
# Hints:
#
# * pull weather only for smaller sample of crashes (250 or so) due to API limits
# * for sending HTTP requests check out "requests" library [here](http://docs.python-requests.org/en/master/)

# %%
import requests
import time
api_key = os.environ["api_worldweather"]
